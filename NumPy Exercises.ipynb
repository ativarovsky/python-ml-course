# %% [markdown]
# # NumPy Exercises

# %%
import numpy as np

# %% [markdown]
# Create array of 10 zeros

# %%
np.zeros(10)

# %% [markdown]
# Create array of 10 ones

# %%
np.ones(10)

# %% [markdown]
# Create array of 10 fives

# %%
np.ones(10)*5

# %% [markdown]
# Create array of integers from 10 to 50

# %%
np.arange(10,51, 1)

# %% [markdown]
# Create an array of even integers from 10 to 50

# %%
np.arange(0,51,2)

# %% [markdown]
# Create a 3x3 matrix with values ranging from 0 to 8

# %%
arr = np.arange(0,9,1)

# %%
arr

# %%
arr.reshape(3,3)

# %% [markdown]
# Create a 3x3 identity matrix

# %%
np.eye(3)

# %% [markdown]
# Use NumPy to generate a number between 0 and 1

# %%
np.random.rand(1)

# %% [markdown]
# Use NumPy to generate an array of 25 random numbers sampled from a standard normal distribution

# %%
np.random.randn(25)

# %% [markdown]
# Create a 10x10 matrix of evenly spaced numbers between 0 and 1, incremented by 0.01

# %%
arr = np.arange(0.01, 1.01, 0.01)

# %%
arr

# %%
arr.reshape(10, 10)

# %% [markdown]
# Create array of 20 linearly spaced points between 0 and 1

# %%
np.linspace(0,1,20)

# %%
mat = np.arange(1,26).reshape(5,5)

# %%
mat

# %%
mat[2:,1:]

# %% [markdown]
# Now just want the 20

# %%
mat[3,4]

# %% [markdown]
# Now just want the 2, 7, and 12

# %%
mat[:3, 1].reshape(3,1)

# %% [markdown]
# Now want array([21, 22, 23, 24, 25]), basically the last row

# %%
mat[4,]

# %% [markdown]
# Now want last two rows

# %%
mat[3:5,]

# %% [markdown]
# Now get the sum of all values in mat

# %%
np.sum(mat)

# %%
np.std(mat)

# %% [markdown]
# Sum of all columns in mat

# %%
np.sum(mat[:,1])
