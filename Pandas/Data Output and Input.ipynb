# %% [markdown]
# # Data Input and Output

# %%
pwd
# Out:
# 'C:\\Users\\ativarovsky.ALTAMEDORG\\Documents\\python-ml-course\\Pandas'

# %%
import pandas as pd

# %%
df = pd.read_csv('example')

# %%
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df.to_csv('My_output') # note that this saves an index (Unnamed below), use index = False if you don't want this

# %%
pd.read_csv('My_output')
# Out:
#    Unnamed: 0   a   b   c   d
# 0           0   0   1   2   3
# 1           1   4   5   6   7
# 2           2   8   9  10  11
# 3           3  12  13  14  15

# %%
df.to_excel('Excel_Sample2.xlsx', sheet_name = 'NewSheet')

# %% [markdown]
# ### Reading html files (web scraping)

# %%
data = pd.read_html('http://www.fdic.gov/bank/individual/failed/banklist.html')

# %%
type(data) # note this is a list of several tables
# Out:
# list

# %%
data
# Out:
# [                                          Bank Name               City  \
#  0                       Tioga-Franklin Savings Bank       Philadelphia
#  1                               Small Business Bank             Lenexa
#  2     Kentland Federal Savings and Loan Association           Kentland
#  3           Community Bank and Trust - West Georgia           LaGrange
#  4                 Metropolitan Capital Bank & Trust            Chicago
#  5                      The Santa Anna National Bank         Santa Anna
#  6                              Pulaski Savings Bank            Chicago
#  7                The First National Bank of Lindsay            Lindsay
#  8             Republic First Bank dba Republic Bank       Philadelphia
#  9                                     Citizens Bank           Sac City
#  10                         Heartland Tri-State Bank            Elkhart
#  11                              First Republic Bank      San Francisco
# ...

# %%
data[0]
# Out:
#                                           Bank Name               City  \
# 0                       Tioga-Franklin Savings Bank       Philadelphia
# 1                               Small Business Bank             Lenexa
# 2     Kentland Federal Savings and Loan Association           Kentland
# 3           Community Bank and Trust - West Georgia           LaGrange
# 4                 Metropolitan Capital Bank & Trust            Chicago
# 5                      The Santa Anna National Bank         Santa Anna
# 6                              Pulaski Savings Bank            Chicago
# 7                The First National Bank of Lindsay            Lindsay
# 8             Republic First Bank dba Republic Bank       Philadelphia
# 9                                     Citizens Bank           Sac City
# 10                         Heartland Tri-State Bank            Elkhart
# 11                              First Republic Bank      San Francisco
# ...

# %% [markdown]
# ### Working with SQL

# %%
import pyodbc

# %%
#from sqlalchemy import create_engine

# %%
conn = pyodbc.connect(
    "DRIVER={ODBC Driver 18 for SQL Server};"
    "SERVER=DB-PROD-REPORT;"
    "DATABASE=ALTAMED_DATASCIENCE;"
    "Trusted_Connection=yes;"  # Or UID=user;PWD=password
    "TrustServerCertificate=yes;"
)

# %%
query = "SELECT TOP 100* FROM dbo.VG_ER_Visits"

# %%
df = pd.read_sql_query(query, conn)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
df.head()
# Out:
#   ER_Claim_Number ER_Visit_Date ER_DiagCode                   ER_Loc_Name  \
# 0              NA    2026-09-17          NA   Cedars-Sinai Medical Center
# 1              NA    2026-09-17          NA  Queen of the Valley Hospital
# 2              NA    2026-09-16          NA  Queen of the Valley Hospital
# 3              NA    2026-09-16          NA  Queen of the Valley Hospital
# 4              NA    2026-09-14          NA  Queen of the Valley Hospital
#
#   Source_System PatientEpicID PrimaryMRN LANES_admit_reason  \
# 0         LANES       Z521602   20108735               None
# 1         LANES       Z665145   20252273               None
# 2         LANES       Z665145   20252273               None
# 3         LANES       Z348616     311188               None
# 4         LANES        Z54641     838672               None
#
#   ER_CCSR_Category_1  ER_Classification  ... Viva_Gold_Eff_Dt  \
# 0               None  ER - Unclassified  ...       2022-07-01
# ...
