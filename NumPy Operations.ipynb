# %% [markdown]
# # NumPy Operations

# %%
import numpy as np

# %%
arr = np.arange(0,11)

# %%
arr

# %%
arr + arr

# %%
arr - arr

# %%
arr * arr

# %%
arr * 2 # scalar

# %%
arr - 100

# %%
arr ** 2 # squares everything

# %%
np.sqrt(arr) # square root

# %%
np.min(arr)

# %%
arr.max()

# %%
np.sin(arr)
